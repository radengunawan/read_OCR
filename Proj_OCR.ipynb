# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = cv2.imread('recent3.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.imread('recent3a.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_string(img))
plt.imshow(img)
# Out:
# PELE TRIAS
#
# Part :1243-001TVNK
#
# QTY :000250 LOTNO:000000000220425
# DIC :210516 VIC:04339
# Serial No. : 000000000001
# VIN: 6 AE eT RG IRA 8]
# Dest: CONN Terminal Blocks Packing 1840366
#
# Male.2pin Pitch=3.5mm, SIT, PHOENIX RoHS pape ae
#
# RoHS
#
# PO_NO: 412134
#
# Total Shipping qty: 1500
# CA: 4 «= ¢
#
# Shipping Date: 20220425

# %%
img = cv2.imread('recent3b.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_string(img))
plt.imshow(img)
# Out:
# BD ono. AHO 0 0 WI WA
# 6500294154
#
# ee HTM
#
# 10159154-007; F
# P/N. INN 0000 0 WH
# 601781558203
# MName.: | MON 00 A I)
#
# 340295
#
# Mfg D/C: HN
#
# D213
#
# eT ae
#
# 1211021
#
# 7% MND &) :
# Q25 | i
# Max. Safe Temp. 260%¢ |
#
# Pb-free | an

# %%
img = cv2.imread('recent3c.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_string(img))
plt.imshow(img)
# Out:
# VEE TRIAS
#
# Part :1243-001TVNK
# QTY :000250 LOT NO :000000000220425
# D/C :210516 V/C:04339
# Serial No. : 000000000002
# VIN: PAE FBR OD BR ZS
# Dese:CONN Terminal Blocks Packing 1840366
# ‘Male 2pin, Pitch=3. 5mm, S/T, fk PHOENIX,ROHS sa?
#
# PO_NO: 412134
#
# Total Shipping qty: 1500
# C/N: 2 - 6
#
# _ Shipping Date: 20220425

# %%
img = cv2.imread('recent3c.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_boxes(img))
plt.imshow(img)
# Out:
# ~ 0 1033 932 1112 0
# ~ 0 932 50 955 0
# ~ 0 955 629 1033 0
# ~ 506 932 629 955 0
# ~ 784 932 932 1033 0
# V 211 956 254 999 0
# E 262 958 303 998 0
# E 311 955 351 998 0
# T 367 954 404 997 0
# R 383 939 405 1003 0
# I 407 961 419 995 0
# A 421 960 451 995 0
# S 454 960 477 995 0
# P 50 897 75 931 0
# a 80 896 102 922 0
# r 96 895 120 931 0
# t 109 895 139 929 0
# : 159 895 165 921 0
# 1 176 901 191 935 0
# 2 202 900 225 935 0
# 4 229 900 252 934 0
# 3 256 899 280 934 0
# - 284 908 297 915 0
# 0 299 899 323 934 0
# 0 326 899 350 933 0
# 1 356 899 370 933 0
# T 382 898 408 933 0
# V 411 897 440 932 0
# N 445 897 472 932 0
# K 479 897 506 931 0
# Q 48 844 75 874 0
# T 80 845 101 874 0
# Y 105 845 127 873 0
# : 144 845 147 864 0
# 0 159 844 177 873 0
# 0 181 844 199 874 0
# 0 203 844 221 873 0
# 2 226 843 243 873 0
# 5 248 843 266 873 0
# 0 270 843 288 872 0
# L 393 843 410 872 0
# O 415 843 441 872 0
# T 446 843 466 872 0
# N 482 842 504 872 0
# O 509 842 535 871 0
# ...

# %%
img = cv2.imread('recent3c.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hImg, wImg, _ = img.shape
boxes = pytesseract.image_to_boxes(img)

# %%
boxes = pytesseract.image_to_boxes(img)
print(boxes)
# Out:
# ~ 0 1033 932 1112 0
# ~ 0 932 50 955 0
# ~ 0 955 629 1033 0
# ~ 506 932 629 955 0
# ~ 784 932 932 1033 0
# V 211 956 254 999 0
# E 262 958 303 998 0
# E 311 955 351 998 0
# T 367 954 404 997 0
# R 383 939 405 1003 0
# I 407 961 419 995 0
# A 421 960 451 995 0
# S 454 960 477 995 0
# P 50 897 75 931 0
# a 80 896 102 922 0
# r 96 895 120 931 0
# t 109 895 139 929 0
# : 159 895 165 921 0
# 1 176 901 191 935 0
# 2 202 900 225 935 0
# 4 229 900 252 934 0
# 3 256 899 280 934 0
# - 284 908 297 915 0
# 0 299 899 323 934 0
# 0 326 899 350 933 0
# 1 356 899 370 933 0
# T 382 898 408 933 0
# V 411 897 440 932 0
# N 445 897 472 932 0
# K 479 897 506 931 0
# Q 48 844 75 874 0
# T 80 845 101 874 0
# Y 105 845 127 873 0
# : 144 845 147 864 0
# 0 159 844 177 873 0
# 0 181 844 199 874 0
# 0 203 844 221 873 0
# 2 226 843 243 873 0
# 5 248 843 266 873 0
# 0 270 843 288 872 0
# L 393 843 410 872 0
# O 415 843 441 872 0
# T 446 843 466 872 0
# N 482 842 504 872 0
# O 509 842 535 871 0
# ...

# %%
img = cv2.imread('recent3a.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hImg, wImg, _ = img.shape
boxes = pytesseract.image_to_boxes(img)


for b in boxes.splitlines():
    #print(b)
    b = b.split(' ')
    #print(b)
    x,y,w,h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
    cv2.rectangle(img, (x, y), (w,h), (255,0,255),1)
    
plt.imshow(img)
cv2.imwrite('test102.jpg',img)
# Out:
# True

# %%
img = cv2.imread('recent4.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (470, 1258, 3)

# %%
hImg, wImg, _ = img.shape
print(hImg)
# Out:
# 470

# %%
img = cv2.imread('recent3b.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hImg, wImg, _ = img.shape
boxes = pytesseract.image_to_boxes(img)


for b in boxes.splitlines():
    print(b)
    b = b.split(' ')
    print(b)
    x,y,w,h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
    cv2.rectangle(img, (x, hImg -y), (w, hImg -h), (0,0,255),1)
    
    #cv2.circle(img, (x,hImg - y), radius=0, color=(0, 0, 255), thickness=10)
    #cv2.circle(img, (w,hImg - h), radius=0, color=(255, 0, 0), thickness=10)
    #cv2.putText(img, b[0], (x,hImg - y), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0),2, cv2.LINE_AA, False)
    
    
    
plt.imshow(img)
cv2.imwrite('test102.jpg',img)
# Out:
# B 0 1107 16 1132 0
# ['B', '0', '1107', '16', '1132', '0']
# D 48 1075 73 1128 0
# ['D', '48', '1075', '73', '1128', '0']
# o 120 1034 167 1067 0
# ['o', '120', '1034', '167', '1067', '0']
# n 181 1031 204 1062 0
# ['n', '181', '1031', '204', '1062', '0']
# o 195 1027 217 1067 0
# ['o', '195', '1027', '217', '1067', '0']
# . 209 1027 252 1059 0
# ['.', '209', '1027', '252', '1059', '0']
# A 289 1005 333 1063 0
# ['A', '289', '1005', '333', '1063', '0']
# H 332 1003 359 1061 0
# ['H', '332', '1003', '359', '1061', '0']
# O 364 999 410 1059 0
# ['O', '364', '999', '410', '1059', '0']
# 0 467 992 496 1055 0
# ['0', '467', '992', '496', '1055', '0']
# 0 562 983 611 1047 0
# ['0', '562', '983', '611', '1047', '0']
# W 630 980 659 1039 0
# ['W', '630', '980', '659', '1039', '0']
# I 665 974 726 1036 0
# ['I', '665', '974', '726', '1036', '0']
# W 783 969 799 1030 0
# ['W', '783', '969', '799', '1030', '0']
# A 798 965 838 1024 0
# ['A', '798', '965', '838', '1024', '0']
# ...

# %%
# !echo "# read_OCR" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin git@github.com:radengunawan/read_OCR.git
# !git push -u origin main
# Out:
# Initialized empty Git repository in D:/.git/
# [master (root-commit) a08bf95] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !echo "# read_OCR" >> README.md

# %%
# !git init
# Out:
# Initialized empty Git repository in D:/Proj_OCR/.git/

# %%
# !git add README.md

# %%
# !git commit -m "first commit"
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
# 	Proj_OCR.ipynb
# 	read_OCR/
# 	recent3a.jpg
# 	recent3b.jpg
# 	recent3c.jpg
# 	recent4.jpg
# 	test102.jpg
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
pwd
# Out:
# 'D:\\'

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/radengunawan/read_OCR.git
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git clone https://github.com/radengunawan/read_OCR.git
# Out:
# Cloning into 'read_OCR'...
# ...
